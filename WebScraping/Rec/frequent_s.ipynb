# %%
import pandas as pd
df = pd.read_pickle('reviews0')
alist = df.groupby('userID')['attraction'].apply(lambda x: x.values)

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
a= alist.loc[alist.apply(len) > 2]

# %%
alist = a.loc[a.index != 'A TripAdvisor Member']

# %%
te = TransactionEncoder()
te_ary = te.fit(alist).transform(alist)
dd = pd.DataFrame(te_ary, columns=te.columns_)
frequent_itemsets = apriori(dd, min_support=0.01, use_colnames=True)
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6).sort_values('lift')
# Out:
#                                             antecedants  \
# 896   (Camden Market, V&A - Victoria and Albert Museum)
# 1655                        (St. James's Park, Big Ben)
# 8445  (Tower of London, British Museum, Westminster ...
# 396           (Westminster Abbey, Houses of Parliament)
# 1703                         (Tower of London, Big Ben)
# 2631                  (Covent Garden, Trafalgar Square)
# 2899   (Shakespeare's Globe Theatre, Westminster Abbey)
# 8537          (Tower of London, Natural History Museum)
# 5681            (Westminster Abbey, London Underground)
# 3064                    (Borough Market, Covent Garden)
# 8500  (Churchill War Rooms, Tower of London, Westmin...
# 6800             (St. James's Park, London Underground)
# 4074                  (Camden Market, National Gallery)
# 6037               (Borough Market, London Underground)
# 3377                    (Greenwich, London Underground)
# 7681                      (Harrods, London Underground)
# ...

# %%
frequent_itemsets.loc[frequent_itemsets.itemsets.apply(len) > 2]
# Out:
#      support                                           itemsets
# 82  0.065648  [British Museum, Coca-Cola London Eye, Tower o...
# 83  0.050558  [British Museum, National Gallery, Tower of Lo...
# 84  0.055966  [Coca-Cola London Eye, London Underground, Tow...
# 85  0.056828  [Coca-Cola London Eye, Tower Bridge, Tower of ...

# %%
from mlxtend.frequent_patterns import association_rules

# %%
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6).sort_values('lift')
# Out:
#                             antecedants             consequents  \
# 1              (Madame Tussauds London)  (Coca-Cola London Eye)
# 0  (Coca-Cola London Eye, Tower Bridge)       (Tower of London)
# 3                   (Westminster Abbey)       (Tower of London)
# 2   (Tower of London, National Gallery)        (British Museum)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 1            0.129945            0.340644  0.081346    0.626008  1.837716
# 0            0.091181            0.337400  0.056828    0.623239  1.847182
# 3            0.143919            0.337400  0.092533    0.642949  1.905599
# 2            0.079302            0.307913  0.050558    0.637545  2.070535
#
#    leverage  conviction
# 1  0.037081    1.763019
# 0  0.026063    1.758676
# 3  0.043974    1.855759
# 2  0.026140    1.909443
